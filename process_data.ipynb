# %%
import pylidc as pl
import numpy as np
import matplotlib.pyplot as plt

# %%
scan = pl.query(pl.Scan).first()

print("Paciente:", scan.patient_id)
# Out:
# Paciente: LIDC-IDRI-0078

# %%
import configparser
configparser.SafeConfigParser = configparser.ConfigParser

vol = scan.to_volume()

print("Shape volumen:", vol.shape)
# Out:
# Loading dicom files ... This may take a moment.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 4
#       1 import configparser
#       2 configparser.SafeConfigParser = configparser.ConfigParser
# ----> 4 vol = scan.to_volume()
#       6 print("Shape volumen:", vol.shape)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pylidc\Scan.py:642, in Scan.to_volume(self, verbose)
#     638 def to_volume(self, verbose=True):
#     639     """
#     640     Return the scan as a 3D numpy array volume.
#     641     """
# --> 642     images = self.load_all_dicom_images(verbose=verbose)
#     644     volume = np.stack(
#     645         [
#     646             x.pixel_array * x.RescaleSlope + x.RescaleIntercept
#    (...)
#     649         axis=-1,
#     650     ).astype(np.int16)
#     651     return volume
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pylidc\Scan.py:288, in Scan.load_all_dicom_images(self, verbose)
#     261 """
#     262 Load all the DICOM images assocated with this scan and return as list.
#     263
#    (...)
#     284
#     285 """
#     286 if verbose: print("Loading dicom files ... This may take a moment.")
# --> 288 path = self.get_path_to_dicom_files()
#     289 fnames = [fname for fname in os.listdir(path)
#     290                     if fname.endswith('.dcm') and not fname.startswith(".")]
#     291 images = []
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pylidc\Scan.py:215, in Scan.get_path_to_dicom_files(self)
#     211 if not os.path.exists(dicompath):
#     212     msg = ("Could not establish path to dicom files. Have you "
#     213            "specified the `path` option in the configuration "
#     214            "file {}?")
# --> 215     raise RuntimeError(msg.format(_get_config_file()))
#     217 base = os.path.join(dicompath, self.patient_id)
#     219 if not os.path.exists(base):
#
# RuntimeError: Could not establish path to dicom files. Have you specified the `path` option in the configuration file C:\Users\loann\pylidc.conf?

# %%
anns = scan.annotations

print("Número de anotaciones:", len(anns))
# Out:
# Número de anotaciones: 13

# %%
import numpy as np
np.int = int
nodules = scan.cluster_annotations()

print("Número de nódulos:", len(nodules))
# Out:
# Número de nódulos: 4

# %%
nod = nodules[0]

print("Radiólogos que lo anotaron:", len(nod))
# Out:
# Radiólogos que lo anotaron: 4

# %%
# threshold=0.5 → mayoría de radiólogos
from pylidc.utils import consensus
mask = pl.utils.consensus(nod, clevel=0.5)[0]

print("Shape máscara:", mask.shape)
# Out:
# Shape máscara: (34, 44, 6)

# %%
bbox = pl.utils.consensus(nod, clevel=0.5)[1]

print("Bounding box:", bbox)
# Out:
# Bounding box: (slice(np.int64(294), np.int64(328), None), slice(np.int64(306), np.int64(350), None), slice(np.int64(23), np.int64(29), None))

# %%
zmin, zmax = bbox[2].start, bbox[2].stop
ymin, ymax = bbox[1].start, bbox[1].stop
xmin, xmax = bbox[0].start, bbox[0].stop

ct_patch = vol[xmin:xmax, ymin:ymax, zmin:zmax]

print("Shape patch CT:", ct_patch.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       2 ymin, ymax = bbox[1].start, bbox[1].stop
#       3 xmin, xmax = bbox[0].start, bbox[0].stop
# ----> 5 ct_patch = vol[xmin:xmax, ymin:ymax, zmin:zmax]
#       7 print("Shape patch CT:", ct_patch.shape)
#
# NameError: name 'vol' is not defined
